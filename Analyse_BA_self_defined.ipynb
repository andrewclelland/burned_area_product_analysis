# %% [markdown]
# # Prelims

# %%
# Install the Google Earth Engine Python API and geemap, if necessary
# !pip install earthengine-api
# !pip install geemap

# %%
import geemap
import ee
ee.Authenticate()
ee.Initialize(project='spherical-berm-323321') # <-- Edit project linked to your individual GEE account

# %%
# Borders
countriessimp = ee.FeatureCollection("FAO/GAUL_SIMPLIFIED_500m/2015/level1")
countiessimp = ee.FeatureCollection("FAO/GAUL_SIMPLIFIED_500m/2015/level2")
countries = ee.FeatureCollection("FAO/GAUL/2015/level1")
boreal = ee.Image("users/andyc97/Shapefiles/rogers_boreal_regions")

# Canada
# Northern territories
nunavut = countriessimp.filter(ee.Filter.eq("ADM1_CODE", 832)) # treat Nunavut separately
keewatin = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12639))
nwterritories = countriessimp.filter(ee.Filter.eq("ADM1_CODE", 830))
nterritories = countriessimp.filter(ee.Filter.eq("ADM1_CODE", 837)).merge(nwterritories) # Yukon

# West coast and prairies
britcol = countriessimp.filter(ee.Filter.eq("ADM1_CODE", 826)) # only West Coast state
alberta = countriessimp.filter(ee.Filter.eq("ADM1_CODE", 825))
saskatch = countriessimp.filter(ee.Filter.eq("ADM1_CODE", 836)).merge(alberta)
prairies = countriessimp.filter(ee.Filter.eq("ADM1_CODE", 827)).merge(saskatch) # Manitoba
westcoprair = britcol.merge(prairies)

# Central and Atlantic
quebec = countriessimp.filter(ee.Filter.eq("ADM1_CODE", 835))
ontario = countriessimp.filter(ee.Filter.eq("ADM1_CODE", 833))
central = countriessimp.filter(ee.Filter.eq("ADM1_CODE", 835)).merge(ontario) # Quebec
newbruns = countriessimp.filter(ee.Filter.eq("ADM1_CODE", 828))
novascot = countriessimp.filter(ee.Filter.eq("ADM1_CODE", 831)).merge(newbruns)
princeed = countriessimp.filter(ee.Filter.eq("ADM1_CODE", 834)).merge(novascot)
atlantic = countriessimp.filter(ee.Filter.eq("ADM1_CODE", 829)).merge(princeed) # Newfoundland
centatlan = central.merge(atlantic)

# Alaska and merge Canada
alaska = countriessimp.filter(ee.Filter.eq("ADM1_NAME", "Alaska"))
canada = countriessimp.filter(ee.Filter.eq("ADM0_NAME", "Canada"))
canalaska = alaska.merge(canada)

# Alaska separate
aleuteast = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 28758))
anchorage = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 28579)).merge(aleuteast)
bristolbay = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 28760)).merge(anchorage)
denali = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 28761)).merge(bristolbay)
fairbanksns = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 28762)).merge(denali)
haines = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 28763)).merge(fairbanksns)
juneau = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 28764)).merge(haines)
kenai = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 28765)).merge(juneau)
kodiak = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 28767)).merge(kenai)
lakeandpenin = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 28768)).merge(kodiak)
matanuskasus = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 28769)).merge(lakeandpenin)
northslope = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 28770)).merge(matanuskasus)
nwarctic = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 28771)).merge(northslope)
sitka = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 28772)).merge(nwarctic)
alaska1 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 28774)).merge(sitka) # Yakutat

aleutwest = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 154724))

bethel = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 154725))
dillingham = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 154726)).merge(bethel)
hoonahangoon = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 154727)).merge(dillingham)
ketchikangate = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 154728)).merge(hoonahangoon)
nome  = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 154729)).merge(ketchikangate)
petersburg = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 154730)).merge(nome)
powhyder = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 154731)).merge(petersburg)
skagway = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 154732)).merge(powhyder)
sefairbanks = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 154733)).merge(skagway)
valdezcordova = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 154734)).merge(sefairbanks)
wadehampton = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 154735)).merge(valdezcordova)
wrangell = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 154736)).merge(wadehampton)
alaska2 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 154737)).merge(wrangell) # Yukon-Koyukuk

# Urals Federal District
kurgan = countries.filter(ee.Filter.eq("ADM1_CODE", 2526))
sverdlovsk = countries.filter(ee.Filter.eq("ADM1_CODE", 2559)).merge(kurgan)
tyumen = countries.filter(ee.Filter.eq("ADM1_CODE", 2566)).merge(sverdlovsk)
khantymansi = countries.filter(ee.Filter.eq("ADM1_CODE", 2518)).merge(tyumen)
chelyabinsk = countries.filter(ee.Filter.eq("ADM1_CODE", 2499)).merge(khantymansi)
urals = countries.filter(ee.Filter.eq("ADM1_CODE", 2575)).merge(chelyabinsk) # Yamalo-Nenets

# Siberian Federal District
altayrep = countries.filter(ee.Filter.eq("ADM1_CODE", 2489))
altaykrai = countries.filter(ee.Filter.eq("ADM1_CODE", 2490)).merge(altayrep)
irkutsk = countries.filter(ee.Filter.eq("ADM1_CODE", 2506)).merge(altaykrai)
ustorda = countries.filter(ee.Filter.eq("ADM1_CODE", 2570)).merge(irkutsk)
kemerovo = countries.filter(ee.Filter.eq("ADM1_CODE", 2515)).merge(ustorda)
krasnoyarsk = countries.filter(ee.Filter.eq("ADM1_CODE", 2525)).merge(kemerovo)
evenk = countries.filter(ee.Filter.eq("ADM1_CODE", 2504)).merge(krasnoyarsk)
taymyr = countries.filter(ee.Filter.eq("ADM1_CODE", 2562)).merge(evenk)
novosibirsk = countries.filter(ee.Filter.eq("ADM1_CODE", 2541)).merge(taymyr)
omsk = countries.filter(ee.Filter.eq("ADM1_CODE", 2542)).merge(novosibirsk)
tomsk = countries.filter(ee.Filter.eq("ADM1_CODE", 2563)).merge(omsk)
tyva = countries.filter(ee.Filter.eq("ADM1_CODE", 2567)).merge(tomsk)
siberia = countries.filter(ee.Filter.eq("ADM1_CODE", 2517)).merge(tyva) # Khakasiya

# Talucci Siberia
irkutsk = countries.filter(ee.Filter.eq("ADM1_CODE", 2506))
ustorda = countries.filter(ee.Filter.eq("ADM1_CODE", 2570)).merge(irkutsk)
krasnoyarsk = countries.filter(ee.Filter.eq("ADM1_CODE", 2525)).merge(ustorda)
evenk = countries.filter(ee.Filter.eq("ADM1_CODE", 2504)).merge(krasnoyarsk)
talsib = countries.filter(ee.Filter.eq("ADM1_CODE", 2562)).merge(evenk) # Taymyr

# Far East Federal District
amur = countries.filter(ee.Filter.eq("ADM1_CODE", 2491))
buryatiya = countries.filter(ee.Filter.eq("ADM1_CODE", 2497)).merge(amur)
yevrey = countries.filter(ee.Filter.eq("ADM1_CODE", 2577)).merge(buryatiya)
kamchatka = countries.filter(ee.Filter.eq("ADM1_CODE", 2512)).merge(yevrey)
koryak = countries.filter(ee.Filter.eq("ADM1_CODE", 2522)).merge(kamchatka)
magadan = countries.filter(ee.Filter.eq("ADM1_CODE", 2531)).merge(koryak)
primorskiy = countries.filter(ee.Filter.eq("ADM1_CODE", 2547)).merge(magadan)
sakha = countries.filter(ee.Filter.eq("ADM1_CODE", 2551)).merge(primorskiy)
fareast1 = countries.filter(ee.Filter.eq("ADM1_CODE", 2516)).merge(sakha) # Khabarovsk

chukotka = countries.filter(ee.Filter.eq("ADM1_CODE", 2501))
chita = countries.filter(ee.Filter.eq("ADM1_CODE", 2500)).merge(chukotka)
fareast2 = countries.filter(ee.Filter.eq("ADM1_CODE", 2488)).merge(chita) # Aginskiy Buryatskiy

# Talucci Far East
amur = countries.filter(ee.Filter.eq("ADM1_CODE", 2491))
buryatiya = countries.filter(ee.Filter.eq("ADM1_CODE", 2497)).merge(amur)
koryak = countries.filter(ee.Filter.eq("ADM1_CODE", 2522)).merge(buryatiya)
magadan = countries.filter(ee.Filter.eq("ADM1_CODE", 2531)).merge(koryak)
sakha = countries.filter(ee.Filter.eq("ADM1_CODE", 2551)).merge(magadan)
talfareast1 = countries.filter(ee.Filter.eq("ADM1_CODE", 2516)).merge(sakha) # Khabarovsk

chukotka = countries.filter(ee.Filter.eq("ADM1_CODE", 2501))
chita = countries.filter(ee.Filter.eq("ADM1_CODE", 2500)).merge(chukotka)
talfareast2 = countries.filter(ee.Filter.eq("ADM1_CODE", 2488)).merge(chita) # Aginskiy Buryatskiy

# Merge Siberia
fareast = fareast1.merge(fareast2)
ursib = urals.merge(siberia)
siball = ursib.merge(fareast)
talfareast = talfareast1.merge(talfareast2)
talall = talsib.merge(talfareast)

# Geometry region list
# Canada
canregions = [(nterritories, 'N Territories'), (keewatin, 'Keewatin'), (westcoprair, 'Westcoprair'),
              (centatlan, 'Centatlan')]
ccicanregions = [(nterritories, 'N Territories'), (keewatin, 'Keewatin'), (westcoprair, 'Westcoprair'),
                 (central, 'Central'), (atlantic, 'Atlantic')]
abovecanregions = [(nterritories, 'N Territories'), (keewatin, 'Keewatin'), (westcoprair, 'Westcoprair'),
                   (quebec, 'Quebec'), (ontario, 'Ontario'), (atlantic, 'Atlantic')]
nbacregions = [(nterritories, 'N Territories'), (nunavut, 'Nunavut'), (westcoprair, 'Westcoprair'),
               (centatlan, 'Centatlan')]

# Alaska
akregions = [(alaska1, 'Alaska 1'), (alaska2, 'Alaska 2'), (aleutwest, 'Aleut West')]
mtbsregions = [(alaska, 'Alaska')]

# CA + AK
allregions = [(nterritories, 'N Territories'), (keewatin, 'Keewatin'), (westcoprair, 'Westcoprair'),
              (central, 'Central'), (atlantic, 'Atlantic'), (alaska1, 'Alaska 1'),
              (alaska2, 'Alaska 2'), (aleutwest, 'Aleut West')]
aboveallregions = [(nterritories, 'N Territories'), (keewatin, 'Keewatin'), (westcoprair, 'Westcoprair'),
                   (quebec, 'Quebec'), (ontario, 'Ontario'), (atlantic, 'Atlantic'),
                   (alaska1, 'Alaska 1'), (alaska2, 'Alaska 2'), (aleutwest, 'Aleut West')]
mtbsnbacregions = [(nterritories, 'N Territories'), (nunavut, 'Nunavut'), (westcoprair, 'Westcoprair'),
                   (centatlan, 'Centatlan'), (alaska, 'Alaska')]

# Siberia
ccirusregions = [(urals, 'Urals'), (siberia, 'Siberia'), (fareast1, 'Far East 1'),
                 (fareast2, 'Far East 2')]
ikirusregions = [(siberia, 'Siberia'), (fareast1, 'Far East 1'), (fareast2, 'Far East 2')]
mcdrusregions = [(urals, 'Urals'), (siberia, 'Siberia'), (fareast, 'Far East')]
talccirusregions = [(talsib, 'Tal Siberia'), (talfareast1, 'Tal Far East 1'), (talfareast2, 'Tal Far East 2')]
talmcdrusregions = [(talsib, 'Tal Siberia'), (talfareast, 'Tal Far East')]
cciallrusregions = [(urals, 'Urals'), (siberia, 'Siberia'), (fareast1, 'Far East 1'),
                    (fareast2, 'Far East 2'), (talsib, 'Tal Siberia'), (talfareast1, 'Tal Far East 1'),
                    (talfareast2, 'Tal Far East 2')]
mcdallrusregions = [(urals, 'Urals'), (siberia, 'Siberia'), (fareast, 'Far East'),
                    (talsib, 'Tal Siberia'), (talfareast, 'Tal Far East')]

# Palettes
jdVis = {'palette': ['ff0000', 'fd4100', 'fb8200', 'f9c400', 'f2ff00', 'b6ff05',
                    '7aff0a', '3eff0f', '02ff15', '00ff55', '00ff99', '00ffdd',
                    '00ddff', '0098ff', '0052ff', '0210ff', '3a0dfb', '7209f6',
                    'a905f1', 'e102ed', 'ff00cc', 'ff0089', 'ff0047', 'ff0004'],
         'min':1, 'max':366}

clVis = {'palette': ['ff0000', 'fd4100', 'fb8200', 'f9c400', 'f2ff00', 'b6ff05',
                    '7aff0a', '3eff0f', '02ff15', '00ff55', '00ff99', '00ffdd',
                    '00ddff', '0098ff', '0052ff', '0210ff', '3a0dfb', '7209f6',
                    'a905f1', 'e102ed', 'ff00cc', 'ff0089', 'ff0047', 'ff0004'],
         'min':1, 'max':100}

lcVis = {'palette': ['ffff64', 'aaf0f0', 'dcf064', 'c8c864', '006400', '00a000',
                     '003c00', '285000', '788200', '8ca000', 'be9600', '966400',
                     'ffb432', 'ffdcd2', 'ffebaf', '009678', '00dc82']}

ikiVis = {'palette': ['ffffff', 'ff0000', 'ffa500', 'ffff00', '008000'],
          'min':0, 'max':4}

gfedVis = {'palette': ['ff0000', 'fd4100', 'fb8200', 'f9c400', 'f2ff00', 'b6ff05',
                       '7aff0a', '3eff0f', '02ff15', '00ff55', '00ff99', '00ffdd',
                       '00ddff', '0098ff', '0052ff', '0210ff', '3a0dfb', '7209f6',
                       'a905f1', 'e102ed', 'ff00cc', 'ff0089', 'ff0047', 'ff0004'],
           'min':0, 'max':2.7}

gfed5oldVis = {'palette': ['ff0000', 'fd4100', 'fb8200', 'f9c400', 'f2ff00', 'b6ff05',
                           '7aff0a', '3eff0f', '02ff15', '00ff55', '00ff99', '00ffdd',
                           '00ddff', '0098ff', '0052ff', '0210ff', '3a0dfb', '7209f6',
                          'a905f1', 'e102ed', 'ff00cc', 'ff0089', 'ff0047', 'ff0004'],
               'min':0, 'max':12400}

gfed5newVis = {'palette': ['ff0000', 'fd4100', 'fb8200', 'f9c400', 'f2ff00', 'b6ff05',
                           '7aff0a', '3eff0f', '02ff15', '00ff55', '00ff99', '00ffdd',
                           '00ddff', '0098ff', '0052ff', '0210ff', '3a0dfb', '7209f6',
                          'a905f1', 'e102ed', 'ff00cc', 'ff0089', 'ff0047', 'ff0004'],
               'min':0, 'max':775}

modliveVis = {'palette': ['ff0000', 'fb8200', '7aff0a', '02ff15', '00ddff',
                          '0052ff', '3a0dfb', 'ff00cc', 'ff0047',],
           'min':0, 'max':9}

aboveVis = {'palette': ['ff0000', 'fd4100', 'fb8200', 'f9c400', 'f2ff00', 'b6ff05',
                       '7aff0a', '3eff0f', '02ff15', '00ff55', '00ff99', '00ffdd',
                       '00ddff', '0098ff', '0052ff', '0210ff', '3a0dfb', '7209f6',
                       'a905f1', 'e102ed', 'ff00cc', 'ff0089', 'ff0047', 'ff0004'],
           'min':0, 'max':1000}

avhrrVis = {'palette': ['ff0000', 'fd4100', 'fb8200', 'f9c400', 'f2ff00', 'b6ff05',
                        '7aff0a', '3eff0f', '02ff15', '00ff55', '00ff99', '00ffdd',
                        '00ddff', '0098ff', '0052ff', '0210ff', '3a0dfb', '7209f6',
                        'a905f1', 'e102ed', 'ff00cc', 'ff0089', 'ff0047', 'ff0004'],
           'min':1, 'max':30980356}

# %%
# Group NASA 1979-2000 into one FeatureCollection
nasa_1979 = ee.FeatureCollection("users/andyc97/nasa_1979-2000/nasa_1979")
nasa_1980 = ee.FeatureCollection("users/andyc97/nasa_1979-2000/nasa_1980").merge(nasa_1979)
nasa_1981 = ee.FeatureCollection("users/andyc97/nasa_1979-2000/nasa_1981").merge(nasa_1980)
nasa_1982 = ee.FeatureCollection("users/andyc97/nasa_1979-2000/nasa_1982").merge(nasa_1981)
nasa_1983 = ee.FeatureCollection("users/andyc97/nasa_1979-2000/nasa_1983").merge(nasa_1982)
nasa_1984 = ee.FeatureCollection("users/andyc97/nasa_1979-2000/nasa_1984").merge(nasa_1983)
nasa_1985 = ee.FeatureCollection("users/andyc97/nasa_1979-2000/nasa_1985").merge(nasa_1984)
nasa_1986 = ee.FeatureCollection("users/andyc97/nasa_1979-2000/nasa_1986").merge(nasa_1985)
nasa_1987 = ee.FeatureCollection("users/andyc97/nasa_1979-2000/nasa_1987").merge(nasa_1986)
nasa_1988 = ee.FeatureCollection("users/andyc97/nasa_1979-2000/nasa_1988").merge(nasa_1987)
nasa_1989 = ee.FeatureCollection("users/andyc97/nasa_1979-2000/nasa_1989").merge(nasa_1988)
nasa_1990 = ee.FeatureCollection("users/andyc97/nasa_1979-2000/nasa_1990").merge(nasa_1989)
nasa_1991 = ee.FeatureCollection("users/andyc97/nasa_1979-2000/nasa_1991").merge(nasa_1990)
nasa_1992 = ee.FeatureCollection("users/andyc97/nasa_1979-2000/nasa_1992").merge(nasa_1991)
nasa_1993 = ee.FeatureCollection("users/andyc97/nasa_1979-2000/nasa_1993").merge(nasa_1992)
nasa_1994 = ee.FeatureCollection("users/andyc97/nasa_1979-2000/nasa_1994").merge(nasa_1993)
nasa_1995 = ee.FeatureCollection("users/andyc97/nasa_1979-2000/nasa_1995").merge(nasa_1994)
nasa_1996 = ee.FeatureCollection("users/andyc97/nasa_1979-2000/nasa_1996").merge(nasa_1995)
nasa_1997 = ee.FeatureCollection("users/andyc97/nasa_1979-2000/nasa_1997").merge(nasa_1996)
nasa_1998 = ee.FeatureCollection("users/andyc97/nasa_1979-2000/nasa_1998").merge(nasa_1997)
nasa_1999 = ee.FeatureCollection("users/andyc97/nasa_1979-2000/nasa_1999").merge(nasa_1998)
nasa_collection = ee.FeatureCollection("users/andyc97/nasa_1979-2000/nasa_2000").merge(nasa_1999) # nasa_2000

# Group monthly NASA 1982-2000 into one FeatureCollection
nasa_monthly_1982 = ee.FeatureCollection("users/andyc97/nasa_monthly_1982-2000/nasa_monthly_1982")
nasa_monthly_1983 = ee.FeatureCollection("users/andyc97/nasa_monthly_1982-2000/nasa_monthly_1983").merge(nasa_monthly_1982)
nasa_monthly_1984 = ee.FeatureCollection("users/andyc97/nasa_monthly_1982-2000/nasa_monthly_1984").merge(nasa_monthly_1983)
nasa_monthly_1985 = ee.FeatureCollection("users/andyc97/nasa_monthly_1982-2000/nasa_monthly_1985").merge(nasa_monthly_1984)
nasa_monthly_1986 = ee.FeatureCollection("users/andyc97/nasa_monthly_1982-2000/nasa_monthly_1986").merge(nasa_monthly_1985)
nasa_monthly_1987 = ee.FeatureCollection("users/andyc97/nasa_monthly_1982-2000/nasa_monthly_1987").merge(nasa_monthly_1986)
nasa_monthly_1988 = ee.FeatureCollection("users/andyc97/nasa_monthly_1982-2000/nasa_monthly_1988").merge(nasa_monthly_1987)
nasa_monthly_1989 = ee.FeatureCollection("users/andyc97/nasa_monthly_1982-2000/nasa_monthly_1989").merge(nasa_monthly_1988)
nasa_monthly_1990 = ee.FeatureCollection("users/andyc97/nasa_monthly_1982-2000/nasa_monthly_1990").merge(nasa_monthly_1989)
nasa_monthly_1991 = ee.FeatureCollection("users/andyc97/nasa_monthly_1982-2000/nasa_monthly_1991").merge(nasa_monthly_1990)
nasa_monthly_1992 = ee.FeatureCollection("users/andyc97/nasa_monthly_1982-2000/nasa_monthly_1992").merge(nasa_monthly_1991)
nasa_monthly_1993 = ee.FeatureCollection("users/andyc97/nasa_monthly_1982-2000/nasa_monthly_1993").merge(nasa_monthly_1992)
nasa_monthly_1994 = ee.FeatureCollection("users/andyc97/nasa_monthly_1982-2000/nasa_monthly_1994").merge(nasa_monthly_1993)
nasa_monthly_1995 = ee.FeatureCollection("users/andyc97/nasa_monthly_1982-2000/nasa_monthly_1995").merge(nasa_monthly_1994)
nasa_monthly_1996 = ee.FeatureCollection("users/andyc97/nasa_monthly_1982-2000/nasa_monthly_1996").merge(nasa_monthly_1995)
nasa_monthly_1997 = ee.FeatureCollection("users/andyc97/nasa_monthly_1982-2000/nasa_monthly_1997").merge(nasa_monthly_1996)
nasa_monthly_1998 = ee.FeatureCollection("users/andyc97/nasa_monthly_1982-2000/nasa_monthly_1998").merge(nasa_monthly_1997)
nasa_monthly_1999 = ee.FeatureCollection("users/andyc97/nasa_monthly_1982-2000/nasa_monthly_1999").merge(nasa_monthly_1998)
nasa_monthly = ee.FeatureCollection("users/andyc97/nasa_monthly_1982-2000/nasa_monthly_2000").merge(nasa_monthly_1999) # nasa_monthly_2000

# individual ABoVE-FED years
above2001 = ee.Image("users/andyc97/ABoVE-FED_2001-2020/above-fed_2001")
above2002 = ee.Image("users/andyc97/ABoVE-FED_2001-2020/above-fed_2002")
above2003 = ee.Image("users/andyc97/ABoVE-FED_2001-2020/above-fed_2003")
above2004 = ee.Image("users/andyc97/ABoVE-FED_2001-2020/above-fed_2004")
above2005 = ee.Image("users/andyc97/ABoVE-FED_2001-2020/above-fed_2005")
above2006 = ee.Image("users/andyc97/ABoVE-FED_2001-2020/above-fed_2006")
above2007 = ee.Image("users/andyc97/ABoVE-FED_2001-2020/above-fed_2007")
above2008 = ee.Image("users/andyc97/ABoVE-FED_2001-2020/above-fed_2008")
above2009 = ee.Image("users/andyc97/ABoVE-FED_2001-2020/above-fed_2009")
above2010 = ee.Image("users/andyc97/ABoVE-FED_2001-2020/above-fed_2010")
above2011 = ee.Image("users/andyc97/ABoVE-FED_2001-2020/above-fed_2011")
above2012 = ee.Image("users/andyc97/ABoVE-FED_2001-2020/above-fed_2012")
above2013 = ee.Image("users/andyc97/ABoVE-FED_2001-2020/above-fed_2013")
above2014 = ee.Image("users/andyc97/ABoVE-FED_2001-2020/above-fed_2014")
above2015 = ee.Image("users/andyc97/ABoVE-FED_2001-2020/above-fed_2015")
above2016 = ee.Image("users/andyc97/ABoVE-FED_2001-2020/above-fed_2016")
above2017 = ee.Image("users/andyc97/ABoVE-FED_2001-2020/above-fed_2017")
above2018 = ee.Image("users/andyc97/ABoVE-FED_2001-2020/above-fed_2018")
above2019 = ee.Image("users/andyc97/ABoVE-FED_2001-2020/above-fed_2019")
above2020 = ee.Image("users/andyc97/ABoVE-FED_2001-2020/above-fed_2020")

# %% [markdown]
# # GABAM borders and polygons

# %%
# Polygons
gabkeewatself = ee.Geometry.Polygon([[-104.984881, 67.007428], [-105.018179, 64.479895], [-102.003341, 64.18964], [-102.008899, 60.001733], [-101.245579, 60.004479],
   [110.714984, 59.288332], [110.29763, 58.983991], [109.792411, 58.972667], [109.24326, 59.377988], [110.539256, 61.164437], [109.792411, 61.322997],
   [109.616682, 61.814664], [109.924207, 62.380185], [109.045566, 63.538763], [108.166924, 63.597448], [108.474449, 64.301822], [108.013162, 64.177679],
   [105.708559, 64.633292], [89.97868, 63.509375]])

# %%
# Boreal/tundra borders
# WWF Boreal/Tundra Ecosystems
wwfboreal = ee.FeatureCollection('users/andyc97/Shapefiles/wwf_ecosystems').filter('BIOME==6')
tundra = ee.FeatureCollection('users/andyc97/Shapefiles/wwf_ecosystems').filter('BIOME==11')
wwf = wwfboreal.merge(tundra)

# AK/CA boreal shapefile
# Tundra
alastelirantun = ee.FeatureCollection('users/andyc97/Shapefiles/wwf_ecosystems').filter("ECO_NAME=='Alaska-St. Elias Range tundra'")
aleisltun = ee.FeatureCollection('users/andyc97/Shapefiles/wwf_ecosystems').filter("ECO_NAME=='Aleutian Islands tundra'")
arccoatun = ee.FeatureCollection('users/andyc97/Shapefiles/wwf_ecosystems').filter("ECO_NAME=='Arctic coastal tundra'")
arcfootun = ee.FeatureCollection('users/andyc97/Shapefiles/wwf_ecosystems').filter("ECO_NAME=='Arctic foothills tundra'")
bafcoatun = ee.FeatureCollection('users/andyc97/Shapefiles/wwf_ecosystems').filter("ECO_NAME=='Baffin coastal tundra'")
berlowtun = ee.FeatureCollection('users/andyc97/Shapefiles/wwf_ecosystems').filter("ECO_NAME=='Beringia lowland tundra'")
berupltun = ee.FeatureCollection('users/andyc97/Shapefiles/wwf_ecosystems').filter("ECO_NAME=='Beringia upland tundra'")
brobrirantun = ee.FeatureCollection('users/andyc97/Shapefiles/wwf_ecosystems').filter("ECO_NAME=='Brooks-British Range tundra'")
davhigtun = ee.FeatureCollection('users/andyc97/Shapefiles/wwf_ecosystems').filter("ECO_NAME=='Davis Highlands tundra'")
higarctun = ee.FeatureCollection('users/andyc97/Shapefiles/wwf_ecosystems').filter("ECO_NAME=='High Arctic tundra'")
intyukalaalptun = ee.FeatureCollection('users/andyc97/Shapefiles/wwf_ecosystems').filter("ECO_NAME=='Interior Yukon-Alaska alpine tundra'")
lowarctun = ee.FeatureCollection('users/andyc97/Shapefiles/wwf_ecosystems').filter("ECO_NAME=='Low Arctic tundra'")
midarctun = ee.FeatureCollection('users/andyc97/Shapefiles/wwf_ecosystems').filter("ECO_NAME=='Middle Arctic tundra'")
ogimacalptun = ee.FeatureCollection('users/andyc97/Shapefiles/wwf_ecosystems').filter("ECO_NAME=='Ogilvie-MacKenzie alpine tundra'")
paccoamoutun = ee.FeatureCollection('users/andyc97/Shapefiles/wwf_ecosystems').filter("ECO_NAME=='Pacific Coastal Mountain icefields and tundra'")
tormoutun = ee.FeatureCollection('users/andyc97/Shapefiles/wwf_ecosystems').filter("ECO_NAME=='Torngat Mountain tundra'")
tunfinal = (alastelirantun.merge(aleisltun).merge(arccoatun).merge(arcfootun).merge(bafcoatun).merge(berlowtun).merge(berupltun).merge(brobrirantun)
.merge(davhigtun).merge(higarctun).merge(intyukalaalptun).merge(lowarctun).merge(midarctun).merge(ogimacalptun).merge(paccoamoutun).merge(tormoutun))

# Boreal
alapenmontai = ee.FeatureCollection('users/andyc97/Shapefiles/wwf_ecosystems').filter("ECO_NAME=='Alaska Peninsula montane taiga'")
cencanshifor = ee.FeatureCollection('users/andyc97/Shapefiles/wwf_ecosystems').filter("ECO_NAME=='Central Canadian Shield forests'")
cooinltai = ee.FeatureCollection('users/andyc97/Shapefiles/wwf_ecosystems').filter("ECO_NAME=='Cook Inlet taiga'")
copplatai = ee.FeatureCollection('users/andyc97/Shapefiles/wwf_ecosystems').filter("ECO_NAME=='Copper Plateau taiga'")
eascanshitai = ee.FeatureCollection('users/andyc97/Shapefiles/wwf_ecosystems').filter("ECO_NAME=='Eastern Canadian Shield taiga'")
eascanfor = ee.FeatureCollection('users/andyc97/Shapefiles/wwf_ecosystems').filter("ECO_NAME=='Eastern Canadian forests'")
intalayukloltai = ee.FeatureCollection('users/andyc97/Shapefiles/wwf_ecosystems').filter("ECO_NAME=='Interior Alaska-Yukon lowland taiga'")
midconcanfor = ee.FeatureCollection('users/andyc97/Shapefiles/wwf_ecosystems').filter("ECO_NAME=='Mid-Continental Canadian forests'")
midcanshifor = ee.FeatureCollection('users/andyc97/Shapefiles/wwf_ecosystems').filter("ECO_NAME=='Midwestern Canadian Shield forests'")
musslalakfor = ee.FeatureCollection('users/andyc97/Shapefiles/wwf_ecosystems').filter("ECO_NAME=='Muskwa-Slave Lake forests'")
newhigfor = ee.FeatureCollection('users/andyc97/Shapefiles/wwf_ecosystems').filter("ECO_NAME=='Newfoundland Highland forests'")
norcanshitai = ee.FeatureCollection('users/andyc97/Shapefiles/wwf_ecosystems').filter("ECO_NAME=='Northern Canadian Shield taiga'")
norcorfor = ee.FeatureCollection('users/andyc97/Shapefiles/wwf_ecosystems').filter("ECO_NAME=='Northern Cordillera forests'")
nortertai = ee.FeatureCollection('users/andyc97/Shapefiles/wwf_ecosystems').filter("ECO_NAME=='Northwest Territories taiga'")
souavaburoce = ee.FeatureCollection('users/andyc97/Shapefiles/wwf_ecosystems').filter("ECO_NAME=='South Avalon-Burin oceanic barrens'")
souhudbaytai = ee.FeatureCollection('users/andyc97/Shapefiles/wwf_ecosystems').filter("ECO_NAME=='Southern Hudson Bay taiga'")
yukintdryfor = ee.FeatureCollection('users/andyc97/Shapefiles/wwf_ecosystems').filter("ECO_NAME=='Yukon Interior dry forests'")
borfinal = (alapenmontai.merge(cencanshifor).merge(cooinltai).merge(copplatai).merge(eascanshitai).merge(eascanfor).merge(intalayukloltai)
.merge(midconcanfor).merge(midcanshifor).merge(musslalakfor).merge(newhigfor).merge(norcanshitai).merge(norcorfor).merge(nortertai).merge(souavaburoce)
.merge(souhudbaytai).merge(yukintdryfor))

# Canada
canbor1 = ee.Geometry.Polygon([[-139.042969, 59.998986], [-138.696899, 59.916483], [-138.641968, 59.786816], [-137.197266, 59.034902], [-136.461182, 59.428316], [-136.466675, 59.472989],
   [-136.378784, 59.456243], [-136.295013, 59.469501], [-136.222229, 59.544761], [-136.237335, 59.560071], [-136.349945, 59.60179], [-136.299133, 59.621242],
   [174.067383, 62.441242], [173.496094, 62.522458], [172.836914, 62.349609], [172.023926, 62.461567], [170.81543, 62.267923], [170.332031, 62.257696],
   [169.936523, 62.512318], [170.068359, 62.684228], [169.716797, 62.643868], [169.057617, 62.955223], [168.936768, 62.932735], [168.431396, 63.084814],
   [169.189453, 63.538763], [169.519043, 63.548552], [169.562988, 63.821288], [169.299316, 63.937372], [168.75, 63.995235], [168.508301, 64.292292],
   [168.156738, 64.301822], [167.67334, 64.311349], [167.211914, 64.623877], [166.794434, 64.520097], [165.849609, 64.557881], [165.739746, 64.71788],
   [165.234375, 64.764759], [165.053101, 64.851272], [165.031128, 64.677969], [164.855347, 64.682667], [164.514771, 64.837262], [164.20166, 64.932853],
   [164.003906, 64.862941], [163.839111, 64.860608], [163.564453, 64.932853]])

sibbor = sibbor1.union(sibbor2).union(sibbor3)
sib_intersect = sibfinal.geometry().intersection(right=rogsousib)

# %%
# Borders for GABAM
countriessimp = ee.FeatureCollection("FAO/GAUL_SIMPLIFIED_500m/2015/level1")
countiessimp = ee.FeatureCollection("FAO/GAUL_SIMPLIFIED_500m/2015/level2")
countries = ee.FeatureCollection("FAO/GAUL/2015/level1")

# Canada
# Northern territories
gabnunavut = countriessimp.filter(ee.Filter.eq("ADM1_CODE", 832))
gabkeewatin = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12639)) # Polygon

# NW Territories
gabregion2 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 190731))
gabregion3 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 190732))
gabregion4 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 190733))
gabregion5 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 190734))
gabregion6 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 190735))
gabyukon = countriessimp.filter(ee.Filter.eq("ADM1_CODE", 837))
gabnwterritories = (gabregion2.merge(gabregion3).merge(gabregion4).merge(gabregion5)
                              .merge(gabregion6).merge(gabyukon))

gabregion1 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 190730)) # Polygon

# British Columbia
gabalberclay = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12539))
gabbulknech = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12540))
gabcapital = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12541))
gabcariboo = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12542))
gabccoast = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12543))
gabckoot = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12544))
gabcokan = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12545))
gabcolshus = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12546))
gabcowichval = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12548))
gabekoot = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12549))
gabffgeorge = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12551))
gabfrasval = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12550))
gabgvancouv = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12552))
gabbritcol1 = (gabalberclay.merge(gabbulknech).merge(gabcapital).merge(gabcariboo)
                           .merge(gabccoast).merge(gabckoot).merge(gabcokan)
                           .merge(gabcolshus).merge(gabcowichval).merge(gabekoot)
                           .merge(gabffgeorge).merge(gabfrasval).merge(gabgvancouv))

gabkootbound = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12554))
gabnanaimo = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12556))
gabnokanagan = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12557))
gabnrockies = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12558))
gabokansimil = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12559))
gabpeacriv = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12560))
gabpowellriv = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12561))
gabsquamishlill = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12563))
gabstikine = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12564))
gabsuncoast = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12565))
gabthompsonnico = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12566))
gabcomoxval = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 190728))
gabbritcol2 = (gabkootbound.merge(gabnanaimo).merge(gabnokanagan).merge(gabnrockies)
                           .merge(gabokansimil).merge(gabpeacriv).merge(gabpowellriv)
                           .merge(gabsquamishlill).merge(gabstikine).merge(gabsuncoast)
                           .merge(gabthompsonnico).merge(gabcomoxval))

gabmountwad = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12555))
gabstrathcona = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 190729))
gabbritcol3 = gabmountwad.merge(gabstrathcona)

gabkitimatstik = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12553))
gabskeenaquech = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12562))

# Prairies
gabalberta = countriessimp.filter(ee.Filter.eq("ADM1_CODE", 825))
gabsaskatch = countriessimp.filter(ee.Filter.eq("ADM1_CODE", 836))
gabmanitoba = countriessimp.filter(ee.Filter.eq("ADM1_CODE", 827))
gabprairies = gabalberta.merge(gabsaskatch).merge(gabmanitoba)

# Ontario
gabbrant = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12642))
gabbruce = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12643))
gabchatkent = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12644))
gabduffer = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12646))
gabdurham = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12647))
gabelgin = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12648))
gabessex = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12649))
gabfront = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12650))
gabgreatsud = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12651))
gabgrey = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12652))
gabhalib = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12654))
gabhalton = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12655))
gabhamilt = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12656))
gabhastin = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12657))
gabhuron = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12658))
gabkawalak = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12659))
gablambton = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12661))
gablanark = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12662))
gablenadd = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12664))
gabniagara = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12668))
gabnorthum = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12670))
gabottawa = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12671))
gabperth = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12675))
gabpboro = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12676))
gabpresruss = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12677))
gabprinceed = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12678))
gabrriver = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12679))
gabrenfrew = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12680))
gabontario1 = (gabbrant.merge(gabbruce).merge(gabchatkent).merge(gabduffer)
                      .merge(gabdurham).merge(gabelgin).merge(gabessex)
                      .merge(gabfront).merge(gabgreatsud).merge(gabgrey)
                      .merge(gabhalib).merge(gabhalton).merge(gabhamilt)
                      .merge(gabhastin).merge(gabhuron).merge(gabkawalak)
                      .merge(gablambton).merge(gablanark).merge(gablenadd)
                      .merge(gabniagara).merge(gabnorthum).merge(gabottawa)
                      .merge(gabperth).merge(gabpboro).merge(gabpresruss)
                      .merge(gabprinceed).merge(gabrriver).merge(gabrenfrew))

gabsimcoe = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12681))
gabstodungle = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12682))
gabtimisk = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12685))
gabtoronto = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12686))
gabwaterloo = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12687))
gabwell = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12688))
gabyork = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12689))
gableegran = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12663))
gabmanit = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12665))
gabmuskoka = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12667))
gabsudbury = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12683))
gaboxford = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12672))
gabmidd = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12666))
gabparsou = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12673))
gabontario2 = (gabsimcoe.merge(gabstodungle).merge(gabtimisk).merge(gabtoronto)
                        .merge(gabwaterloo).merge(gabwell).merge(gabyork)
                        .merge(gableegran).merge(gabmanit).merge(gabmuskoka)
                        .merge(gabsudbury).merge(gaboxford).merge(gabmidd)
                        .merge(gabparsou))

gabpeel = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12674))
gabhaldnorf = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12653))
gabnipiss = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12669))
gabthunbay = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12684))
gabontario3 = gabpeel.merge(gabhaldnorf).merge(gabnipiss).merge(gabthunbay)

gabcochrane = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12645))
gabkenora = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12660))
gabalgoma = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12641))
gabontario4 = gabcochrane.merge(gabkenora).merge(gabalgoma)

# Quebec
gabquebec = countriessimp.filter(ee.Filter.eq("ADM1_CODE", 835))
gab12693 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12693))
gab12694 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12694))
gab12695 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12695))
gab12696 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12696))
gab12697 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12697))
gab12698 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12698))
gab12700 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12700))
gab12702 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12702))
gab12703 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12703))
gab12701 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12701))
gab12704 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12704))
gab12705 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12705))
gab12706 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12706))
gab12708 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12708))
gab12709 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12709))
gab12710 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12710))
gab12714 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12714))
gab12716 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12716))
gab12717 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12717))
gab12718 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12718))
gab12712 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12712))
gab12719 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12719))
gab12720 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12720))
gab12723 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12723))
gab12721 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12721))
gab12724 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12724))
gab12725 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12725))
gab12727 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12727))
gab12726 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12726))
gab12728 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12728))
gab12729 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12729))
gab12730 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12730))
gab12731 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12731))
gab12732 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12732))
gab12733 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12733))
gab12734 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12734))
gab12736 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12736))
gab12750 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 
countriessimp.filter(ee.Filter.eq("ADM1_CODE", 828))
gabnovascot = countriessimp.filter(ee.Filter.eq("ADM1_CODE", 831))
gabprinedisl = countriessimp.filter(ee.Filter.eq("ADM1_CODE", 834))
gabatlantic = gabnewbruns.merge(gabnovascot).merge(gabprinedisl)

# Newfoundland
gabnewdiv1 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12608))
gabnewdiv2 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12609))
gabnewdiv3 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12610))
gabnewdiv4 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12611))
gabnewdiv5 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12612))
gabnewdiv6 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12613))
gabnewdiv7 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12614))
gabnewdiv8 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12615))
gabnewdiv9 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 12616))
gabnewfound = (gabnewdiv1.merge(gabnewdiv2).merge(gabnewdiv3).merge(gabnewdiv4)
                         .merge(gabnewdiv5).merge(gabnewdiv6).merge(gabnewdiv7)
                         .merge(gabnewdiv8).merge(gabnewdiv9))

gabnewdiv10 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 94292)) # Separate
gabnewdiv11 = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 94293)) # Separate

# Alaska
gabanchorage = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 28579))
gabbristolbay = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 28760))
gabdenali = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 28761))
gabfairbanksns = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 28762))
gabhaines = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 28763))
gabjuneau = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 28764))
gabalaska1 = (gabanchorage.merge(gabbristolbay).merge(gabdenali).merge(gabfairbanksns)
                          .merge(gabhaines).merge(gabjuneau))

gabmatanuskasus = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 28769))
gabsitka = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 28772))
gabskagway = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 154732))
gabalaska2 = gabmatanuskasus.merge(gabsitka).merge(gabskagway)

gabdillingham = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 154726))
gabpetersburg = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 154730))
gabalaska3 = gabdillingham.merge(gabpetersburg)

gabsefairbanks = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 154733))
gabwrangell = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 154736))
gabalaska4 = gabsefairbanks.merge(gabwrangell)

gabnwarctic = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 28771))
gabnome  = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 154729))
gabyukonkoyukuk = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 154737))
gabalaska5 = gabnwarctic.merge(gabnome).merge(gabyukonkoyukuk)

gabwadehampton = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 154735))
gabbethel = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 154725))
gabalaska6 = gabwadehampton.merge(gabbethel)

gabkodiak = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 28767))
gablakeandpenin = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 28768))
gabaleuteast = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 28758))
gabalaska7 = gabkodiak.merge(gablakeandpenin).merge(gabaleuteast)

gabkenai = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 28765))
gabvaldezcordova = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 154734))
gabyakutat = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 28774))
gabalaska8 = gabkenai.merge(gabvaldezcordova).merge(gabyakutat)

gabhoonahangoon = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 154727))
gabpowhyder = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 154731))
gabketchikangate = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 154728))
gabalaska9 = gabhoonahangoon.merge(gabpowhyder).merge(gabketchikangate)

gabalaska10 = gabnome.merge(gabskagway).merge(gabvaldezcordova) # for MOD14A1
gabnorthslope = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 28770)) # Separate
gabaleutwest = countiessimp.filter(ee.Filter.eq("ADM2_CODE", 154724)) # Polygon

# Urals Federal District
gabkurgan = countries.filter(ee.Filter.eq("ADM1_CODE", 2526))
gabsverdlovsk = countries.filter(ee.Filter.eq("ADM1_CODE", 2559))
gabtyumen = countries.filter(ee.Filter.eq("ADM1_CODE", 2566))
gabchelyabinsk = countries.filter(ee.Filter.eq("ADM1_CODE", 2499))
gaburals = gabkurgan.merge(gabsverdlovsk).merge(gabtyumen).merge(gabchelyabinsk)

gabkhantymansi = countries.filter(ee.Filter.eq("ADM1_CODE", 2518)) # Separate
gabyamalonenets = countries.filter(ee.Filter.eq("ADM1_CODE", 2575)) # Separate

# Siberian Federal District
gabaltayrep = countries.filter(ee.Filter.eq("ADM1_CODE", 2489))
gabaltaykrai = countries.filter(ee.Filter.eq("ADM1_CODE", 2490))
gabustorda = countries.filter(ee.Filter.eq("ADM1_CODE", 2570))
gabkemerovo = countries.filter(ee.Filter.eq("ADM1_CODE", 2515))
gabomsk = countries.filter(ee.Filter.eq("ADM1_CODE", 2542))
gabkhakasiya = countries.filter(ee.Filter.eq("ADM1_CODE", 2517))
gabsiberia1 = (gabaltayrep.merge(gabaltaykrai).merge(gabustorda).merge(gabkemerovo)
                         .merge(gabomsk).merge(gabkhakasiya))

gabnovosibirsk = countries.filter(ee.Filter.eq("ADM1_CODE", 2541))
gabtomsk = countries.filter(ee.Filter.eq("ADM1_CODE", 2563))
gabtyva = countries.filter(ee.Filter.eq("ADM1_CODE", 2567))
gabsiberia2 = gabnovosibirsk.merge(gabtomsk).merge(gabtyva)

gabevenk = countries.filter(ee.Filter.eq("ADM1_CODE", 2504)) # Separate
gabirkutsk = countries.filter(ee.Filter.eq("ADM1_CODE", 2506)) # Separate
gabkrasnoyarsk = countries.filter(ee.Filter.eq("ADM1_CODE", 2525)) # Separate
gabtaymyr = countriessimp.filter(ee.Filter.eq("ADM1_CODE", 2562)) # Polygon

# Far East Federal District
gabyevrey = countries.filter(ee.Filter.eq("ADM1_CODE", 2577))
gabprimorskiy = countries.filter(ee.Filter.eq("ADM1_CODE", 2547))
gabaginburyat = countries.filter(ee.Filter.eq("ADM1_CODE", 2488))
gabamur = countries.filter(ee.Filter.eq("ADM1_CODE", 2491))
gabfareast1 = gabyevrey.merge(gabprimorskiy).merge(gabaginburyat).merge(gabamur)

gabkamchatka = countries.filter(ee.Filter.eq("ADM1_CODE", 2512))
gabkoryak = countries.filter(ee.Filter.eq("ADM1_CODE", 2522))
gabmagadan = countries.filter(ee.Filter.eq("ADM1_CODE", 2531))
gabfareast2 = gabkamchatka.merge(gabkoryak).merge(gabmagadan)

gabchita = countries.filter(ee.Filter.eq("ADM1_CODE", 2500))
gabburyatiya = countries.filter(ee.Filter.eq("ADM1_CODE", 2497))
gabfareast3 = gabchita.merge(gabburyatiya)

gabkhabarovsk = countries.filter(ee.Filter.eq("ADM1_CODE", 2516)) # Separate
gabsakha = countriessimp.filter(ee.Filter.eq("ADM1_CODE", 2551)) # Polygon
gabchukotka = countriessimp.filter(ee.Filter.eq("ADM1_CODE", 2501)) # Polygon

# Talucci Far East
gabtalfareast1 = gabamur.merge(gabaginburyat)
gabtalfareast2 = gabkoryak.merge(gabmagadan)

# Boreal Siberia
borsakha = countries.filter(ee.Filter.eq("ADM1_CODE", 2551))
sibbor1 = chukotka.merge(borsakha).merge(gabmagadan)
sibbor2 = gabrognnesib.union(sibbor)

# Geometry region list
gabcanregions = [(gabnwterritories, 'NW Territories'), (gabreg1self, 'NW div 1'), (gabkeewatself, 'Keewatin'),
                 (gabbritcol1, 'Brit Col 1'), (gabbritcol2, 'Brit Col 2'), (gabbritcol3, 'Brit Col 3'),
                 (gabskeenaquech, 'Skeenaquech'), (gabkitimatstik, 'Kitimatstik'), (gabprairies, 'Prairies'),
                 (gabontario1, 'Ontario 1'), (gabontario2, 'Ontario 2'), (gabontario3, 'Ontario 3'),
                 (gabontario4, 'Ontario 4'), (gabquebec1, 'Quebec 1'), (gabquebec2, 'Quebec 2'),
                 (gabquebec3, 'Quebec 3'), (gab12776self, 'Quebec 4'), (gabatlantic, 'Atlantic'),
                 (gabnewfound, 'Newfound'), (gabnewdiv10, 'Newdiv 10'), (gabnewdiv11, 'Newdiv 11')]
                  (rognesib, 'Rog NE Sib'), (rogsousib, 'Rog S Sib')]
avhrrallregions = [(nterritories, 'N Territories'), (keewatin, 'Keewatin'), (westcoprair, 'Westcoprair'),
                   (gabquebec1, 'Quebec 1'), (gabquebec2, 'Quebec 2'), (gabquebec3, 'Quebec 3'),
                   (gab12776, 'Quebec 4'), (ontario, 'Ontario'), (atlantic, 'Atlantic'),
                   (gabnewfound, 'Newfound'), (gabnewdiv10, 'Newdiv 10'), (gabnewdiv11, 'Newdiv 11'),
                   (alaska1, 'Alaska 1'), (alaska2, 'Alaska 2'), (aleutwest, 'Aleut West')]
avhgaballregions = [(gabnwterritories, 'NW Territories'), (gabreg1self, 'NW div 1'), (gabkeewatself, 'Keewatin'),
                    (gabbritcol1, 'Brit Col 1'), (gabbritcol2, 'Brit Col 2'), (gabbritcol3, 'Brit Col 3'),
                    (gabskeenaquech, 'Skeenaquech'), (gabkitimatstik, 'Kitimatstik'), (gabprairies, 'Prairies'),
                    (gabontario1, 'Ontario 1'), (gabontario2, 'Ontario 2'), (gabontario3, 'Ontario 3'),
                    (gabontario4, 'Ontario 4'), (gabquebec1, 'Quebec 1'), (gabquebec2, 'Quebec 2'),
                    (gabquebec3, 'Quebec 3'), (gab12776self, 'Quebec 4'), (gabatlantic, 'Atlantic'),
                    (gabnewfound, 'Newfound'), (gabnewdiv10, 'Newdiv 10'), (gabnewdiv11, 'Newdiv 11'),
                    (alaska1, 'Alaska 1'), (alaska2, 'Alaska 2'), (aleutwest, 'Aleut West')]
gaballregions = [(gabnwterritories, 'NW Territories'), (gabreg1self, 'NW div 1'), (gabkeewatself, 'Keewatin'),
                 (gabbritcol1, 'Brit Col 1'), (gabbritcol2, 'Brit Col 2'), (gabbritcol3, 'Brit Col 3'),
                 (gabskeenaquech, 'Skeenaquech'), (gabkitimatstik, 'Kitimatstik'), (gabprairies, 'Prairies'),
                 (gabontario1, 'Ontario 1'), (gabontario2, 'Ontario 2'), (gabontario3, 'Ontario 3'),
                 (gabontario4, 'Ontario 4'), (gabquebec1, 'Quebec 1'), (gabquebec2, 'Quebec 2'),
                 (gabquebec3, 'Quebec 3'), (gab12776self, 'Quebec 4'), (gabatlantic, 'Atlantic'),
                 (gabnewfound, 'Newfound'), (gabnewdiv10, 'Newdiv 10'), (gabnewdiv11, 'Newdiv 11'),
                 (gabalaska1, 'Alaska 1'), (gabalaska2, 'Alaska 2'), (gabalaska3, 'Alaska 3'),
                 (gabalaska4, 'Alaska 4'), (gabalaska5, 'Alaska 5'), (gabalaska6, 'Alaska 6'),
                 (gabalaska7, 'Alaska 7'), (gabalaska8, 'Alaska 8'), (gabalaska9, 'Alaska 9'),
                 (gabalewestself, 'Aleut West'), (gabnorthslope, 'North Slope')]

# Palette
gabamVis = {'palette': ['f00c0c'], 'min':1, 'max':1}

# %% [markdown]
# # Area analysis for self-defined regions

# %%
# import FireCCI data (global) - from 2001 to 2020
dataset = (ee.ImageCollection("ESA/CCI/FireCCI/5_1")
    .filterDate('2001-01-01', '2001-12-31'))

# created burned area and confidence level layers
julianDay = dataset.select('BurnDate')
confLevel = dataset.select('ConfidenceLevel')
landCover = dataset.select('LandCover')

maxJD = julianDay.max()
maxCL = confLevel.max()

CLmask = maxCL.gte(ee.Number(80)) # <-- edit confidence level as necessary
maxJDmasked = maxJD.updateMask(CLmask)

# %%
# Pixel area - Fire CCI
pa = ee.Image.pixelArea()

#extra = [(canbor, 'Canbor')] # add for any extra, individually defined areas

# Get area
# ccicanregions, akregions, cciallrusregions, rogrusregions
for region, region_name in ccicanregions: # <-- change region grouping as necessary to loop over different areas
    img_area = pa.updateMask(maxJDmasked).reduceRegion(
      reducer=ee.Reducer.sum(),
      geometry=region,
      scale=250, bestEffort=False,
      crs='EPSG:4326',
      maxPixels=1e12).get('area')
    burned_area = img_area.getInfo() / 1e10 # Convert to Mha
    print("Region =", region_name)
    print("Burned area =", burned_area)

# %%
# import MCD64A1 dataset (global) - from 2001 to present
dataset2 = (ee.ImageCollection("MODIS/061/MCD64A1")
    .filterDate('2023-01-01', '2023-12-31'))

# created burned area and uncertainty layers
burnDate = dataset2.select('BurnDate')
uncertainty = dataset2.select('Uncertainty')

maxBD = burnDate.max()
maxUC = uncertainty.max()

# %%
# Pixel area - MCD64A1
pa = ee.Image.pixelArea()

#extra = [(sibbor1, 'Sibbor 1'), (sibbor2, 'Sibbor 2')]

# Get area
# canregions, akregions, mcdallrusregions, rogrusregions
for region, region_name in mcdallrusregions:
    img_area = pa.updateMask(maxBD).reduceRegion(
      reducer=ee.Reducer.sum(),
      geometry=region,
      scale=463.31271653, bestEffort=False,
      crs='SR-ORG:6974',
      maxPixels=1e12).get('area')
    burned_area = img_area.getInfo() / 1e10 # Convert to Mha
    print("Region =", region_name)
    print("Pixel count =", burned_area)

# %%
# import GABAM dataset (global) - from 1985 to 2020
# missing 1986,1988,1990,1991,1993,1994,1997,1999
dataset3 = (ee.ImageCollection("projects/sat-io/open-datasets/GABAM")
    .filterDate('2015-01-01', '2015-12-31'))

# created burned area layer
gabam = dataset3.select('b1')
gabammax = gabam.max()

# %%
# Pixel area - GABAM
pa = ee.Image.pixelArea()

#extra = [(canbor, 'Canbor')]

# Get area
# gabcanregions, gabakregions, gaballregions
# gabrusregions, gabtalrusregions, gabrogrusregions
for region, region_name in gaballregions:
    img_area = pa.updateMask(gabammax).reduceRegion(
      reducer=ee.Reducer.sum(),
      geometry=region,
      scale=30, bestEffort=False,
      maxPixels=1e12).get('area')
    burned_area = img_area.getInfo() / 1e10 # Convert to Mha
    print("Region =", region_name)
    print("Pixel count =", burned_area)

# %%
# import MTBS and NBAC datasets (AK/CA) - from 1985 to present
# NBAC starts in 1989
dataset4 = (ee.FeatureCollection("users/spotter/fire_cnn/raw/ak_ca_1985")
              .filter('Year==2000'))
#              .filter('Month==06'))

# Function to calculate and add area property to each feature - 30m
def add_area(feature):
    # Calculate the area of the feature's geometry in square meters
    area = feature.geometry().area()
    return feature.set({'area': area})

# Map the function and calculate the area over the FeatureCollection or AK/CA
#fc_with_area = dataset4.map(add_area) # whole region
#fc_with_area = dataset4.map(add_area).filterBounds(alaska)
fc_with_area = dataset4.map(add_area).filterBounds(nunavut) # nterritories, nunavut, westcoprair, centatlan

total_area = fc_with_area.reduceColumns(
    reducer=ee.Reducer.sum(),
    selectors=['area']
).get('sum')
burned_area = total_area.getInfo() / 1e10 # Convert to Mha

print("Total Area:", burned_area)

# %%
# import Talucci et al. (2022) dataset (Siberia) - from 2001 to 2020
dataset5 = (ee.FeatureCollection("users/andyc97/Shapefiles/talucci_2001-2020")
            .filter('FireYr==2020')
            .filterBounds(rognesib))
#            .filter('MinDay>=182').filter('MinDay<=212'))

# Function to calculate and add area property to each feature
def add_area(feature):
    # Calculate the area of the feature's geometry in square meters
    area = feature.geometry().area()
    return feature.set({'area': area})

# Map the function and calculate the total area over the FeatureCollection
fc_with_area = dataset5.map(add_area)

total_area = fc_with_area.reduceColumns(
    reducer=ee.Reducer.sum(),
    selectors=['area']
).get('sum')
burned_area = total_area.getInfo() / 1e10 # Convert to Mha

print("Total Area:", burned_area)

# %%
# import IKI dataset (Sib + Far East) - from 2006 to 2020
dataset6 = (ee.ImageCollection("users/andyc97/iki_collection")
    .filterDate('2020-01-01', '2020-12-31'))

# created burned area layer and mask out 0 for map
iki = dataset6.select('b1')
ikimax = iki.max()
ikimax = ikimax.updateMask(ikimax.neq(0))

# %%
# Pixel area - IKI
pa = ee.Image.pixelArea()

# Get area
# ikirusregions, talccirusregions, rogrusregions, sibborregions
for region, region_name in sibborregions:
    img_area = pa.updateMask(ikimax).reduceRegion(
      reducer=ee.Reducer.sum(),
      geometry=region,
      scale=230, bestEffort=False,
      maxPixels=1e12).get('area')
    burned_area = img_area.getInfo() / 1e10 # Convert to Mha
    print("Region =", region_name)
    print("Pixel count =", burned_area)

# %%
# DATASET NOT CURRENTLY PUBLISHED
# import NASA-AVHRR perimeter dataset (Siberia) - from 1979 to 2000
# import NASA-AVHRR monthly dataset (Siberia) - from 1982 to 2000
dataset7 = nasa_collection.filter('FireYear==2000').filterBounds(rogsousib)
#dataset7 = nasa_monthly.filter('FireYear==2000').filter("SatImgMnth=='July'")

# Function to calculate and add area property to each feature
def add_area(feature):
    # Calculate the area of the feature's geometry in square meters
    area = feature.geometry().area()
    return feature.set({'area': area})

# Map the function and calculate the total area over the FeatureCollection
fc_with_area = dataset7.map(add_area)

total_area = fc_with_area.reduceColumns(
    reducer=ee.Reducer.sum(),
    selectors=['area']
).get('sum')

print("Total Area:", total_area.getInfo() / 10000000000)

# %%
# import GFED4s dataset (global) - from 1997 to 2016 - yearly only
dataset8 = (ee.ImageCollection("users/andyc97/gfed4s_collection")
    .filterDate('1997-01-01', '1997-12-31'))

# created burned area layer and mask out 0 for map
gfed = dataset8.select('b1')
gfedmax = gfed.max()
gfedmax = gfedmax.updateMask(gfedmax.neq(0))

# %%
# import GFED4s dataset (global) - from 1997 to 2016 - monthly only
dataset8 = ee.Image("users/andyc97/GFED4s_monthly_1997-2016/gfedmonth_201611")

# created burned area layer and mask out 0 for map
gfed = dataset8.select('b1')
#gfed = gfed.updateMask(gfed.neq(0))

# %%
# Pixel area - GFED4s - uses MCD64A1 version 5 (earlier MCD64A1 is version 6)
pa = ee.Image.pixelArea()

#extra = [(sib_intersect, 'Sib intersect')]

# Get area
# gfedcanregions, akregions, gfedallregions, mcdallrusregions, rogrusregions
for region, region_name in gfedallregions:
    img_area = pa.updateMask(gfed).reduceRegion(
      reducer=ee.Reducer.sum(),
      geometry=region,
      scale=27829.87269831839, bestEffort=False,
      crs='EPSG:4326',
      maxPixels=1e12).get('area')
    burned_area = img_area.getInfo() / 1e10 # Convert to Mha
    print("Region =", region_name)
    print("Burned area =", burned_area)

# %%
# import GFED5 dataset (global) - from 1997 to 2020
# 1997-2000 is at 1 deg resolution, 2001-2020 is 0.25 deg
dataset15 = (ee.ImageCollection("users/andyc97/gfed5")
    .filterDate('2001-01-01', '2001-12-31'))

# created burned area layer and mask out 0 for map
gfed5 = dataset15.select('b1')
gfed5max = gfed5.max()
gfed5max = gfed5max.updateMask(gfed5max.neq(0))

# %%
# GFED5 for analysis
gfed5 = ee.Image("users/andyc97/GFED5_1997-2020/gfed5_202004")
gfed5 = gfed5.updateMask(gfed5.neq(0))

#extra = [(sib_intersect, 'Sib intersect')]

# gfedcanregions, akregions, gfedallregions, mcdallrusregions, rogrusregions
for region, region_name in rogrusregions:
    def calculate_pixel_sum(image):
        pixel_sum = image.reduceRegion(
          reducer=ee.Reducer.sum(),
          geometry=region,
#          scale=111319.49079327357, bestEffort=False, # 1997-2000
          scale=27829.87269831839, bestEffort=False, # 2001-2020
          crs='EPSG:4326',
          maxPixels=1e12).get('b1')
        return pixel_sum
    sums = calculate_pixel_sum(gfed5)
    burned_area = sums.getInfo() / 10000 # different methodology here, but output still Mha
    print("Region =", region_name)
    print("Burned area =", burned_area)

# %%
# import ABoVE-FED dataset (AK/CA) - from 2001 to 2020
#dataset9 = (ee.ImageCollection("users/andyc97/above-fed_collection")
#    .filterDate('2004-01-01', '2004-12-31'))
#above = dataset9.select('b1').max()

# created burned area layer and fix projection
# b1 = burned area, b2 = Julian day
year = above2001.select('b1') # change year as required
proj = year.projection().getInfo()
abovemax = year.changeProj(year.projection(), ee.Projection('SR-ORG:6974', proj['transform']))

# %%
# Pixel area - ABoVE-FED
pa = ee.Image.pixelArea()

# Get area
# abovecanregions, akregions
for region, region_name in akregions:
    img_area = pa.updateMask(abovemax).reduceRegion(
      reducer=ee.Reducer.sum(),
      geometry=region,
      scale=463.31271653, bestEffort=False,
      crs='SR-ORG:6974',
      maxPixels=1e12).get('area')
    burned_area = img_area.getInfo() / 1e10 # Convert to Mha
    print("Region =", region_name)
    print("Burned area =", burned_area)

# %%
# import AVHRR-LTDR data (global) - from 1982 to 2018
# missing 1994
dataset10 = (ee.ImageCollection("users/andyc97/avhrr-ltdr_collection_ba")
    .filterDate('2001-01-01', '2001-12-31'))
dataset11 = (ee.ImageCollection("users/andyc97/avhrr-ltdr_collection_cl")
    .filterDate('2001-01-01', '2001-12-31'))
dataset12 = (ee.ImageCollection("users/andyc97/avhrr-ltdr_collection_jd")
    .filterDate('2001-01-01', '2001-12-31'))

# Remove the wrong CL image for 2010-07
target_index = 'avhrr_201007_cl'
dataset11 = dataset11.filter(ee.Filter.neq('system:index', target_index))

# created burned area and confidence level layers
avhrrba = dataset10.select('b1').max()
avhrrcl = dataset11.select('b1').max()
avhrrjd = dataset12.select('b1').max()
avhrrba = avhrrba.updateMask(avhrrba.neq(-2))
avhrrba = avhrrba.updateMask(avhrrba.neq(-1))
avhrrba = avhrrba.updateMask(avhrrba.neq(0))

avhrrclmask = avhrrcl.gte(ee.Number(30)) # <-- edit confidence level as necessary
avhrrbamasked = avhrrba.updateMask(avhrrclmask)
avhrrjdmasked = avhrrjd.updateMask(avhrrclmask)

# %%
# Pixel area - AVHRR-LTDR
pa = ee.Image.pixelArea()

# Get area
# gfedcanregions, akregions, mcdallrusregions, rogrusregions
for region, region_name in akregions:
    img_area = pa.updateMask(avhrrbamasked).reduceRegion(
      reducer=ee.Reducer.sum(),
      geometry=region,
      scale=5565.974539663679, bestEffort=False,
      maxPixels=1e12).get('area')
    burned_area = img_area.getInfo() / 1e10 # Convert to Mha
    print("Region =", region_name)
    print("Burned area =", burned_area)

# %%
# MODIS Active Fires
# import MOD14A1/MYD14A1 dataset (global) - from 2001 to present
dataset13 = ((ee.ImageCollection("MODIS/061/MOD14A1")).merge(ee.ImageCollection("MODIS/061/MYD14A1"))
    .filterDate('2023-12-01', '2023-12-31'))

# created burned area and uncertainty layers
fireMask = dataset13.select('FireMask')

maxFM = fireMask.max()
FMmask = maxFM.gte(ee.Number(8))
maxFMmasked = maxFM.updateMask(FMmask)

# %%
# Pixel area - MOD14A1/MYD14A1
pa = ee.Image.pixelArea()

#extra = [(sib_intersect, 'Sib intersect')]

# Get area
# canregions, mod14akregions, mcdallrusregions, rogrusregions
# Alaska 2 split into gabalaska3,4,6, gabalaska9 and gabalaska10
for region, region_name in mod14akregions:
    img_area = pa.updateMask(maxFMmasked).reduceRegion(
      reducer=ee.Reducer.sum(),
      geometry=region,
      scale=1000, bestEffort=False,
      crs='SR-ORG:6974',
      maxPixels=1e12).get('area')
    burned_area = img_area.getInfo() / 1e10 # Convert to Mha
    print("Region =", region_name)
    print("Pixel count =", burned_area)

# %%
# import ABBA dataset (boreal) - from 2002 to 2022
dataset14 = (ee.ImageCollection("users/andyc97/abba")
    .filterDate('2022-01-01', '2022-12-31'))

# created burned area and uncertainty layers
abba = dataset14.select('b1').max()

# %%
# Pixel area - ABBA
pa = ee.Image.pixelArea()

#extra = [(sibbor1, 'Sibbor 1'), (sibbor2, 'Sibbor 2')]

# Get area
# canregions, akregions, mcdallrusregions, rogrusregions
for region, region_name in mcdallrusregions:
    img_area = pa.updateMask(abba).reduceRegion(
      reducer=ee.Reducer.sum(),
      geometry=region,
      scale=463.313, bestEffort=False,
      crs='SR-ORG:6974',
      maxPixels=1e12).get('area')
    burned_area = img_area.getInfo() / 1e10 # Convert to Mha
    print("Region =", region_name)
    print("Pixel count =", burned_area)

# %%
# import global map
Map = geemap.Map()

# add layers to map
Map.addLayer(maxJDmasked, jdVis, 'Fire CCI Julian Day')
#Map.addLayer(maxBD, jdVis, 'MCD64A1 Julian Day')
#Map.addLayer(gabammax, gabamVis, 'GABAM')
#Map.addLayer(dataset4, {}, 'MTBS/NBAC')
#Map.addLayer(dataset5, {}, 'Anna Talucci')
#Map.addLayer(ikimax, ikiVis, 'IKI')
#Map.addLayer(dataset7, {}, 'NASA-AVHRR')
#Map.addLayer(gfedmax, gfedVis, 'GFED4s')
#Map.addLayer(gfed5max, gfed5newVis, 'GFED5') # old 1997-2000; new 2001-2020
#Map.addLayer(abovemax, aboveVis, 'ABoVE-FED')
#Map.addLayer(avhrrbamasked, avhrrVis, 'AVHRR-LTDR')
#Map.addLayer(maxFMmasked, modliveVis, 'MODIS AF Combined')
#Map.addLayer(abba, gabamVis, 'ABBA')

Map

# %%
# Get coordinates of point clicked on map
def handle_click(**kwargs):
    if kwargs.get('type') == 'click':
        coords = kwargs.get('coordinates')
        print("Marker clicked at coordinates:", coords)

# Add the map click event handler
Map.on_interaction(handle_click)
Map

# %%
# Save polygon drawn on map to be used (for GABAM)
self = Map.user_roi
self.getInfo()

# %%
# Export the FeatureCollection to a SHP file -> use Google Colab
task = ee.batch.Export.table.toDrive(
    collection=ee.FeatureCollection(tunfinal.merge(borfinal)), description='SouSibBor', fileFormat='SHP'
)
task.start()
